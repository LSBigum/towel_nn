# %% [markdown]
# # Set up (+ reproducible results)

# %%
import numpy as np
import tensorflow as tf
import random as rn
import keras
from keras import backend as K
from keras.models import Sequential
from keras.layers import Activation
from keras.layers.core import Dense, Flatten
from keras.optimizers import Adam, SGD
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import *
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt
import math
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
import os
os.environ['PYTHONHASHSEED'] = '0'

# %%
# Setting the seed for numpy-generated random numbers
np.random.seed(54)

# %%
# Setting the seed for Python random numbers
rn.seed(28)

# %%
tf.set_random_seed(753)

# %% [raw]
# K.tensorflow_backend._get_available_gpus()

# %% [raw]
# import tensorflow as tf
# sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.Session(config=config)

# %%
train_path = 'towels/train/'
valid_path = 'towels/validate/'
test_path = 'towels/test/'

# %%
train_datagen = ImageDataGenerator(rotation_range=10, width_shift_range=0.1, height_shift_range=0.1, 
                                   shear_range=0.15, zoom_range=0.1,
                                   channel_shift_range=10., horizontal_flip=False)

# %%
p, d, f = os.walk('towels/train/True').__next__()
train_sample_count = len(f)
p, d, f = os.walk('towels/train/False').__next__()
train_sample_count = train_sample_count + len(f)
train_batch_size = 32

p, d, f = os.walk('towels/validate/True').__next__()
valid_sample_count = len(f)
p, d, f = os.walk('towels/validate/False').__next__()
valid_sample_count = valid_sample_count + len(f)
valid_batch_size = 4

p, d, f = os.walk('towels/test/True').__next__()
test_sample_count = len(f)
p, d, f = os.walk('towels/test/False').__next__()
test_sample_count = test_sample_count + len(f)

# %%
#train_batches = ImageDataGenerator().flow_from_directory(train_path, target_size=(224,224), classes=['True', 'False'], batch_size=10) 
train_batches = train_datagen.flow_from_directory(train_path, target_size=(224,224), classes=['True', 'False'], batch_size=train_batch_size) 
valid_batches = ImageDataGenerator().flow_from_directory(valid_path, target_size=(224,224), classes=['True', 'False'], batch_size=valid_batch_size) 
test_batches = ImageDataGenerator().flow_from_directory(test_path, target_size=(224,224), classes=['True', 'False'], batch_size=test_sample_count)
# Out:
# Found 239 images belonging to 2 classes.
# Found 47 images belonging to 2 classes.
# Found 28 images belonging to 2 classes.

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(12,6), rows=1, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != 3):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(len(ims)):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(titles[i], fontsize=16)
        plt.imshow(ims[i], interpolation=None if interp else 'none')

# %% [raw]
# for img in imgs:
#     #plt.imshow((img * 255).astype(np.uint8))
#     plt.imshow(img/255)

# %%
imgs, labels = next(train_batches)

# %%
plots(imgs, titles=labels, rows = 4)
# Out:
# /home/laus/.virtualenvs/virtual-py3/lib/python3.5/site-packages/matplotlib/text.py:1191: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %% [markdown]
# # Build and train CNN

# %% [raw]
# model = Sequential([
#     Conv2D(32, (3, 3), activation='relu', input_shape=(224,224,3)),
#     Flatten(), # Flatten the Conv2d to a one-dimensional tensor
#     Dense(2, activation='softmax')
# ])

# %% [raw]
# model.compile(Adam(lr=.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# %% [raw]
# model.fit_generator(train_batches, steps_per_epoch=23,
#                    validation_data=valid_batches, validation_steps=11, epochs=20, verbose=2, use_multiprocessing = False)

# %% [markdown]
# # Predict

# %% [raw]
# test_imgs, test_labels = next(test_batches)
# plots(test_imgs, titles=test_labels)

# %% [raw]
# test_labels = test_labels[:,0]
# test_labels

# %% [raw]
# predictions = model.predict_generator(test_batches, steps=1, verbose=0)

# %% [raw]
# predictions

# %% [raw]
# cm = confusion_matrix(test_labels, predictions[:,0])

# %% [raw]
# ax = plt.axes()
# sns.heatmap(cm,annot=True,fmt='.5g', ax = ax)
# plt.xlabel('Predicted label')
# plt.ylabel('True label')
# plt.show()

# %% [markdown]
# # Build Fine-tuned VGG16 model

# %%
vgg16_model = keras.applications.vgg16.VGG16()

# %% [markdown]
# vgg16_model.summary()

# %%
type(vgg16_model)
# Out:
# keras.engine.training.Model

# %%
model = Sequential()
for layer in vgg16_model.layers[:-1]:
    model.add(layer)

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# =================================================================
# Total params: 134,260,544
# Trainable params: 134,260,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
for layer in model.layers:
    layer.trainable = False
    #layer.trainable = True

# %%
#model.add(Dense(512, activation='relu'))
#model.add(Dense(256, activation='relu'))
model.add(Dense(2, activation='softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 8194
# =================================================================
# Total params: 134,268,738
# Trainable params: 134,268,738
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train the fine-tuned VGG16 model

# %%
model.compile(Adam(lr=.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
steps_per_epoch  = math.ceil(train_sample_count/train_batch_size)
validation_steps = math.ceil(valid_sample_count/valid_batch_size)
history = model.fit_generator(train_batches, steps_per_epoch=steps_per_epoch,
                              validation_data=valid_batches, validation_steps=validation_steps, epochs=50, verbose=1, use_multiprocessing=True)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.3319 - acc: 0.6811 - val_loss: 0.3068 - val_acc: 0.8936
# Epoch 2/50
# 8/8 [==============================] - 2s 294ms/step - loss: 0.2855 - acc: 0.8661 - val_loss: 0.6406 - val_acc: 0.8936
# Epoch 3/50
# 8/8 [==============================] - 2s 285ms/step - loss: 0.2911 - acc: 0.9173 - val_loss: 0.3936 - val_acc: 0.8298
# Epoch 4/50
# 8/8 [==============================] - 2s 282ms/step - loss: 0.2651 - acc: 0.9134 - val_loss: 0.2215 - val_acc: 0.9574
# Epoch 5/50
# 8/8 [==============================] - 2s 282ms/step - loss: 0.1713 - acc: 0.9291 - val_loss: 0.2238 - val_acc: 0.9149
# Epoch 6/50
# 8/8 [==============================] - 3s 363ms/step - loss: 0.3240 - acc: 0.9291 - val_loss: 0.1808 - val_acc: 0.9787
# Epoch 7/50
# 8/8 [==============================] - 3s 405ms/step - loss: 0.1552 - acc: 0.9449 - val_loss: 0.5488 - val_acc: 0.7660
# Epoch 8/50
# 8/8 [==============================] - 3s 401ms/step - loss: 0.2107 - acc: 0.9173 - val_loss: 0.2351 - val_acc: 0.9787
# Epoch 9/50
# 8/8 [==============================] - 3s 402ms/step - loss: 0.0961 - acc: 0.9646 - val_loss: 0.3672 - val_acc: 0.9362
# Epoch 10/50
# 8/8 [==============================] - 3s 398ms/step - loss: 0.1093 - acc: 0.9606 - val_loss: 0.3304 - val_acc: 0.9787
# Epoch 11/50
# 8/8 [==============================] - 3s 399ms/step - loss: 0.1158 - acc: 0.9606 - val_loss: 0.5378 - val_acc: 0.8723
# Epoch 12/50
# 8/8 [==============================] - 3s 401ms/step - loss: 0.1270 - acc: 0.9488 - val_loss: 0.3940 - val_acc: 0.9574
# Epoch 13/50
# 8/8 [==============================] - 3s 400ms/step - loss: 0.0956 - acc: 0.9685 - val_loss: 0.3225 - val_acc: 0.9362
# Epoch 14/50
# 8/8 [==============================] - 3s 399ms/step - loss: 0.0307 - acc: 0.9882 - val_loss: 0.3596 - val_acc: 0.9787
# Epoch 35/50
# 8/8 [==============================] - 3s 402ms/step - loss: 0.0146 - acc: 0.9961 - val_loss: 0.5013 - val_acc: 0.9362
# Epoch 36/50
# 8/8 [==============================] - 3s 401ms/step - loss: 0.0065 - acc: 0.9961 - val_loss: 0.3814 - val_acc: 0.9362
# Epoch 37/50
# 8/8 [==============================] - 3s 401ms/step - loss: 0.0425 - acc: 0.9882 - val_loss: 0.4740 - val_acc: 0.9362
# Epoch 38/50
# 8/8 [==============================] - 3s 404ms/step - loss: 0.0140 - acc: 0.9961 - val_loss: 0.3805 - val_acc: 0.9574
# Epoch 39/50
# 8/8 [==============================] - 3s 402ms/step - loss: 0.0315 - acc: 0.9882 - val_loss: 0.4517 - val_acc: 0.9149
# Epoch 40/50
# 8/8 [==============================] - 3s 401ms/step - loss: 0.0235 - acc: 0.9882 - val_loss: 0.2306 - val_acc: 0.9362
# Epoch 41/50
# 8/8 [==============================] - 3s 403ms/step - loss: 0.0389 - acc: 0.9882 - val_loss: 0.5970 - val_acc: 0.8936
# Epoch 42/50
# 8/8 [==============================] - 3s 406ms/step - loss: 0.0233 - acc: 0.9921 - val_loss: 0.6520 - val_acc: 0.9149
# Epoch 43/50
# 8/8 [==============================] - 3s 401ms/step - loss: 0.1214 - acc: 0.9606 - val_loss: 0.7771 - val_acc: 0.8511
# Epoch 44/50
# 8/8 [==============================] - 3s 406ms/step - loss: 0.2568 - acc: 0.9449 - val_loss: 0.0606 - val_acc: 0.9787
# Epoch 45/50
# 8/8 [==============================] - 3s 396ms/step - loss: 0.1196 - acc: 0.9685 - val_loss: 0.1646 - val_acc: 0.9362
# Epoch 46/50
# 8/8 [==============================] - 3s 397ms/step - loss: 0.0571 - acc: 0.9882 - val_loss: 0.1595 - val_acc: 0.9574
# Epoch 47/50
# 8/8 [==============================] - 3s 398ms/step - loss: 0.0973 - acc: 0.9724 - val_loss: 0.0681 - val_acc: 0.9787
# Epoch 48/50
# 8/8 [==============================] - 3s 398ms/step - loss: 0.0371 - acc: 0.9882 - val_loss: 0.1133 - val_acc: 0.9574
# Epoch 49/50
# 8/8 [==============================] - 3s 402ms/step - loss: 0.0613 - acc: 0.9803 - val_loss: 0.2597 - val_acc: 0.9362
# Epoch 50/50
# 8/8 [==============================] - 3s 399ms/step - loss: 0.0349 - acc: 0.9843 - val_loss: 0.4362 - val_acc: 0.9362

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
 
epochs = range(len(acc))
 
plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
 
plt.figure()
 
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
 
plt.show()

# %% [markdown]
# # Predict using fine-tuned VGG16 model

# %%
test_imgs, test_labels = next(test_batches)
plots(test_imgs, titles=test_labels, rows=4)

# %%
test_labels = test_labels[:,0]
#test_labels

# %%
predictions = model.predict_generator(test_batches, steps=1, verbose=0)
#np.round(predictions)

# %%
cm = confusion_matrix(test_labels, np.round(predictions[:,0]))

# %%
ax = plt.axes()
sns.heatmap(cm,annot=True,fmt='.5g', ax = ax) 
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()

# %% [markdown]
# test_batches.class_indices
#
# model.get_weights()
